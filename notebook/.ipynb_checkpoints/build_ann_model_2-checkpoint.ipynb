# %%
import torch
import torchviz
from torch import nn
import torch.nn.functional as F
from torch.nn import Linear,ReLU,Sigmoid,Tanh
import torch.optim as optim
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.metrics import r2_score,mean_squared_error
from math import sqrt
import joblib
from torch.utils.tensorboard import SummaryWriter
import warnings;warnings.simplefilter('ignore')
from tqdm import tqdm_notebook as tqdm
import os
from sklearn.utils import shuffle
import random
random.seed(42)
torch.manual_seed(42)
root = '../data/phase_2/cleaned/'
os.listdir(root)
# Out:
# ['col_names.pkl', 'train(energy).csv', 'train.csv']

# %%
col_names = joblib.load(root+'col_names.pkl')
col_names.keys()
# Out:
# dict_keys(['xna', 'xle', 'xhc', 'xhe', 'fna', 'fle', 'fhc', 'fhe', 'sle', 'shc', 'she', 'case', 'duty', 'Rate_m3', 'Rate_ton'])

# %%
def mape(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def get_col(df,name):
    condition = df.columns.str.contains(name)
    return df.columns[condition].tolist()

# %% [markdown]
# # load data

# %%
df = pd.read_csv(root+'train(energy).csv',index_col=0).dropna(axis=0)
print(df.shape)
df.head()
# Out:
# (16499, 69)
#         Case Conditions_Feed Rate to C013 (Input)_m3/hr  \
# 001-01                                             10.0
# 001-02                                             10.0
# 001-03                                             10.0
# 001-04                                             10.0
# 001-05                                             10.0
#
#         Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr  \
# 001-01                                              100.0
# 001-02                                              100.0
# 001-03                                              100.0
# 001-04                                              100.0
# 001-05                                              100.0
#
#         Case Conditions_C7+ in Light End (Input)_wt%  \
# 001-01                                           2.5
# 001-02                                           5.0
# 001-03                                          10.0
# 001-04                                           2.5
# 001-05                                           5.0
#
#         Case Conditions_C6P- in Heart Cut (Input)_wt%  \
# 001-01                                            1.0
# 001-02                                            1.0
# 001-03                                            1.0
# 001-04                                            1.5
# 001-05                                            1.5
#
#         Naphtha Properties_Oxygen_wt%  Naphtha Properties_Methane_wt%  \
# 001-01                            0.0                             0.0
# 001-02                            0.0                             0.0
# 001-03                            0.0                             0.0
# 001-04                            0.0                             0.0
# 001-05                            0.0                             0.0
#
#         Naphtha Properties_Ethane_wt%  Naphtha Properties_Propane_wt%  \
# 001-01                            0.0                           0.002
# 001-02                            0.0                           0.002
# 001-03                            0.0                           0.002
# 001-04                            0.0                           0.002
# 001-05                            0.0                           0.002
#
#         Naphtha Properties_n-Butane_wt%  Naphtha Properties_i-Pentane_wt%  \
# 001-01                            0.003                          0.025999
# 001-02                            0.003                          0.025999
# 001-03                            0.003                          0.025999
# 001-04                            0.003                          0.025999
# 001-05                            0.003                          0.025999
#
#         ...  Duty_Condenser Heat Duty_Mkcal/hr  \
# 001-01  ...                           3.891577
# 001-02  ...                           3.723144
# 001-03  ...                           3.572479
# 001-04  ...                           3.442118
# 001-05  ...                           3.301176
#
#         Duty_Reboiler Heat Duty_Mkcal/hr  \
# 001-01                          4.252277
# 001-02                          4.071568
# 001-03                          3.900158
# 001-04                          3.759819
# 001-05                          3.607212
#
#         Naphtha Properties_Naphtha Feed Rate_m3/hr  \
# 001-01                                  118.000084
# 001-02                                  118.000000
# 001-03                                  118.000000
# 001-04                                  118.000000
# 001-05                                  118.000084
#
#         Light End Product Properties_Light End Prod. Rate_m3/hr  \
# 001-01                                           7.997900
# 001-02                                           8.445992
# 001-03                                           9.143384
# 001-04                                           7.284074
# 001-05                                           7.697134
#
#         Heart Cut Product Properties_Heart Cut Prod. Rate_m3/hr  \
# 001-01                                         100.000198
# 001-02                                         100.000122
# 001-03                                         100.000008
# 001-04                                         100.000275
# 001-05                                          99.999817
#
#         Heavy End Product Properties_Heavy End Product Rate_m3/hr  \
# 001-01                                          10.001979
# 001-02                                           9.553886
# 001-03                                           8.856608
# 001-04                                          10.715655
# 001-05                                          10.303131
#
#         Naphtha Properties_Naphtha Feed Rate_ton/hr  \
# 001-01                                    86.475102
# 001-02                                    86.475047
# 001-03                                    86.475047
# 001-04                                    86.475047
# 001-05                                    86.475102
#
#         Light End Product Properties_Light End Prod. Rate_ton/hr  \
# 001-01                                           5.469008
# 001-02                                           5.797086
# 001-03                                           6.294930
# 001-04                                           4.978351
# 001-05                                           5.280904
#
#         Heart Cut Product Properties_Heart Cut Prod. Rate_ton/hr  \
# 001-01                                          73.401711
# 001-02                                          73.411102
# 001-03                                          73.435539
# 001-04                                          73.360406
# 001-05                                          73.370414
#
#         Heavy End Product Properties_Heavy End Product Rate_ton/hr
# 001-01                                           7.604384
# 001-02                                           7.266858
# 001-03                                           6.744582
# 001-04                                           8.136289
# 001-05                                           7.823788
#
# [5 rows x 69 columns]

# %% [markdown]
# # calculate density

# %%
density = df[col_names['Rate_ton']].values/df[col_names['Rate_m3']].values
density = pd.DataFrame(density,columns=['NA_density','LE_density','HC_density','HE_density'],index=df.index)
density.head()
# Out:
#         NA_density  LE_density  HC_density  HE_density
# 001-01    0.732839    0.683806    0.734016    0.760288
# 001-02    0.732839    0.686371    0.734110    0.760618
# 001-03    0.732839    0.688468    0.734355    0.761531
# 001-04    0.732839    0.683457    0.733602    0.759290
# 001-05    0.732839    0.686087    0.733705    0.759360

# %% [markdown]
# # duty

# %%
duty = df[col_names['duty']]
duty = duty.drop('Duty_Condenser Heat Duty_Mkcal/hr',axis=1)
duty.head()
# Out:
#         Duty_E062 3.5K Steam Rate_ton/hr  Duty_Reboiler Heat Duty_Mkcal/hr
# 001-01                          2.280675                          4.252277
# 001-02                          2.280843                          4.071568
# 001-03                          2.280798                          3.900158
# 001-04                          2.280843                          3.759819
# 001-05                          2.280675                          3.607212

# %% [markdown]
# # define X,Y

# %%
X = df[col_names['case']].join(df[col_names['xna']])
print(X.shape)
X.head()
# Out:
# (16499, 58)
#         Case Conditions_Feed Rate to C013 (Input)_m3/hr  \
# 001-01                                             10.0
# 001-02                                             10.0
# 001-03                                             10.0
# 001-04                                             10.0
# 001-05                                             10.0
#
#         Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr  \
# 001-01                                              100.0
# 001-02                                              100.0
# 001-03                                              100.0
# 001-04                                              100.0
# 001-05                                              100.0
#
#         Case Conditions_C7+ in Light End (Input)_wt%  \
# 001-01                                           2.5
# 001-02                                           5.0
# 001-03                                          10.0
# 001-04                                           2.5
# 001-05                                           5.0
#
#         Case Conditions_C6P- in Heart Cut (Input)_wt%  \
# 001-01                                            1.0
# 001-02                                            1.0
# 001-03                                            1.0
# 001-04                                            1.5
# 001-05                                            1.5
#
#         Naphtha Properties_Oxygen_wt%  Naphtha Properties_Methane_wt%  \
# 001-01                            0.0                             0.0
# 001-02                            0.0                             0.0
# 001-03                            0.0                             0.0
# 001-04                            0.0                             0.0
# 001-05                            0.0                             0.0
#
#         Naphtha Properties_Ethane_wt%  Naphtha Properties_Propane_wt%  \
# 001-01                            0.0                           0.002
# 001-02                            0.0                           0.002
# 001-03                            0.0                           0.002
# 001-04                            0.0                           0.002
# 001-05                            0.0                           0.002
#
#         Naphtha Properties_n-Butane_wt%  Naphtha Properties_i-Pentane_wt%  \
# 001-01                            0.003                          0.025999
# 001-02                            0.003                          0.025999
# 001-03                            0.003                          0.025999
# 001-04                            0.003                          0.025999
# 001-05                            0.003                          0.025999
#
#         ...  Naphtha Properties_2,2,3,3-Tetramethylhexane_wt%  \
# 001-01  ...                                          1.387972
# 001-02  ...                                          1.387972
# 001-03  ...                                          1.387972
# 001-04  ...                                          1.387972
# 001-05  ...                                          1.387972
#
#         Naphtha Properties_3-Methylnonane_wt%  \
# 001-01                               3.239935
# 001-02                               3.239935
# 001-03                               3.239935
# 001-04                               3.239935
# 001-05                               3.239935
#
#         Naphtha Properties_tert-Butylcyclohexane_wt%  \
# 001-01                                      0.574988
# 001-02                                      0.574988
# 001-03                                      0.574988
# 001-04                                      0.574988
# 001-05                                      0.574988
#
#         Naphtha Properties_n-Decane_wt%  \
# 001-01                         1.168977
# 001-02                         1.168977
# 001-03                         1.168977
# 001-04                         1.168977
# 001-05                         1.168977
#
#         Naphtha Properties_1,2-Diethylbenzene_wt%  \
# 001-01                                   0.753985
# 001-02                                   0.753985
# 001-03                                   0.753985
# 001-04                                   0.753985
# 001-05                                   0.753985
#
#         Naphtha Properties_n-Undecane_wt%  \
# 001-01                           0.220996
# 001-02                           0.220996
# 001-03                           0.220996
# 001-04                           0.220996
# 001-05                           0.220996
#
#         Naphtha Properties_n-Pentylbenzene_wt%  \
# 001-01                                0.043999
# 001-02                                0.043999
# 001-03                                0.043999
# 001-04                                0.043999
# 001-05                                0.043999
#
#         Naphtha Properties_n-Dodecane_wt%  \
# 001-01                              0.004
# 001-02                              0.004
# 001-03                              0.004
# 001-04                              0.004
# 001-05                              0.004
#
#         Naphtha Properties_n-Hexylbenzene_wt%  \
# 001-01                                  0.008
# 001-02                                  0.008
# 001-03                                  0.008
# 001-04                                  0.008
# 001-05                                  0.008
#
#         Naphtha Properties_n-Tridecane_wt%
# 001-01                                 0.0
# 001-02                                 0.0
# 001-03                                 0.0
# 001-04                                 0.0
# 001-05                                 0.0
#
# [5 rows x 58 columns]

# %%
Y = duty.join(density)
print(Y.shape)
Y.head()
# Out:
# (16499, 6)
#         Duty_E062 3.5K Steam Rate_ton/hr  Duty_Reboiler Heat Duty_Mkcal/hr  \
# 001-01                          2.280675                          4.252277
# 001-02                          2.280843                          4.071568
# 001-03                          2.280798                          3.900158
# 001-04                          2.280843                          3.759819
# 001-05                          2.280675                          3.607212
#
#         NA_density  LE_density  HC_density  HE_density
# 001-01    0.732839    0.683806    0.734016    0.760288
# 001-02    0.732839    0.686371    0.734110    0.760618
# 001-03    0.732839    0.688468    0.734355    0.761531
# 001-04    0.732839    0.683457    0.733602    0.759290
# 001-05    0.732839    0.686087    0.733705    0.759360

# %% [markdown]
# # build scale

# %%
mm = MinMaxScaler()

# %% [markdown]
# # scale features

# %%
X[:] = mm.fit_transform(X[:])
X.head()
# Out:
#         Case Conditions_Feed Rate to C013 (Input)_m3/hr  \
# 001-01                                              0.0
# 001-02                                              0.0
# 001-03                                              0.0
# 001-04                                              0.0
# 001-05                                              0.0
#
#         Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr  \
# 001-01                                                0.5
# 001-02                                                0.5
# 001-03                                                0.5
# 001-04                                                0.5
# 001-05                                                0.5
#
#         Case Conditions_C7+ in Light End (Input)_wt%  \
# 001-01                                      0.000000
# 001-02                                      0.333333
# 001-03                                      1.000000
# 001-04                                      0.000000
# 001-05                                      0.333333
#
#         Case Conditions_C6P- in Heart Cut (Input)_wt%  \
# 001-01                                       0.332220
# 001-02                                       0.332220
# 001-03                                       0.332220
# 001-04                                       0.499165
# 001-05                                       0.499165
#
#         Naphtha Properties_Oxygen_wt%  Naphtha Properties_Methane_wt%  \
# 001-01                            0.0                             0.0
# 001-02                            0.0                             0.0
# 001-03                            0.0                             0.0
# 001-04                            0.0                             0.0
# 001-05                            0.0                             0.0
#
#         Naphtha Properties_Ethane_wt%  Naphtha Properties_Propane_wt%  \
# 001-01                            0.0                        0.014084
# 001-02                            0.0                        0.014084
# 001-03                            0.0                        0.014084
# 001-04                            0.0                        0.014084
# 001-05                            0.0                        0.014084
#
#         Naphtha Properties_n-Butane_wt%  Naphtha Properties_i-Pentane_wt%  \
# 001-01                           0.0106                          0.010208
# 001-02                           0.0106                          0.010208
# 001-03                           0.0106                          0.010208
# 001-04                           0.0106                          0.010208
# 001-05                           0.0106                          0.010208
#
#         ...  Naphtha Properties_2,2,3,3-Tetramethylhexane_wt%  \
# 001-01  ...                                          0.336071
# 001-02  ...                                          0.336071
# 001-03  ...                                          0.336071
# 001-04  ...                                          0.336071
# 001-05  ...                                          0.336071
#
#         Naphtha Properties_3-Methylnonane_wt%  \
# 001-01                               0.336166
# 001-02                               0.336166
# 001-03                               0.336166
# 001-04                               0.336166
# 001-05                               0.336166
#
#         Naphtha Properties_tert-Butylcyclohexane_wt%  \
# 001-01                                      0.090949
# 001-02                                      0.090949
# 001-03                                      0.090949
# 001-04                                      0.090949
# 001-05                                      0.090949
#
#         Naphtha Properties_n-Decane_wt%  \
# 001-01                         0.282495
# 001-02                         0.282495
# 001-03                         0.282495
# 001-04                         0.282495
# 001-05                         0.282495
#
#         Naphtha Properties_1,2-Diethylbenzene_wt%  \
# 001-01                                   0.149402
# 001-02                                   0.149402
# 001-03                                   0.149402
# 001-04                                   0.149402
# 001-05                                   0.149402
#
#         Naphtha Properties_n-Undecane_wt%  \
# 001-01                           0.282239
# 001-02                           0.282239
# 001-03                           0.282239
# 001-04                           0.282239
# 001-05                           0.282239
#
#         Naphtha Properties_n-Pentylbenzene_wt%  \
# 001-01                                0.150533
# 001-02                                0.150533
# 001-03                                0.150533
# 001-04                                0.150533
# 001-05                                0.150533
#
#         Naphtha Properties_n-Dodecane_wt%  \
# 001-01                           0.080034
# 001-02                           0.080034
# 001-03                           0.080034
# 001-04                           0.080034
# 001-05                           0.080034
#
#         Naphtha Properties_n-Hexylbenzene_wt%  \
# 001-01                               0.148144
# 001-02                               0.148144
# 001-03                               0.148144
# 001-04                               0.148144
# 001-05                               0.148144
#
#         Naphtha Properties_n-Tridecane_wt%
# 001-01                                 0.0
# 001-02                                 0.0
# 001-03                                 0.0
# 001-04                                 0.0
# 001-05                                 0.0
#
# [5 rows x 58 columns]

# %% [markdown]
# # split train test

# %%
x_col = X.columns.tolist()
y_col = Y.columns.tolist()
df = shuffle(X.join(Y))

# %%
X = df[x_col]
Y = df[y_col]

sp1 = int(len(X)*0.8)
sp2 = int(len(X)*0.9)

X_train,Y_train = X.iloc[:sp1,:],Y.iloc[:sp1,:]
X_valid,Y_valid = X.iloc[sp1:sp2,:],Y.iloc[sp1:sp2,:]
X_test,Y_test = X.iloc[sp2:,:],Y.iloc[sp2:,:]

print(X_train.shape,X_valid.shape,X_test.shape)
print(Y_train.shape,Y_valid.shape,Y_test.shape)
# Out:
# (13199, 58) (1650, 58) (1650, 58)
# (13199, 6) (1650, 6) (1650, 6)

# %% [markdown]
# # to torch tensor

# %%
X_train = torch.tensor(X_train.values,dtype=torch.float).cuda()
X_valid = torch.tensor(X_valid.values,dtype=torch.float).cuda()
X_test = torch.tensor(X_test.values,dtype=torch.float).cuda()

Y_train = torch.tensor(Y_train.values,dtype=torch.float).cuda()
Y_valid = torch.tensor(Y_valid.values,dtype=torch.float).cuda()
Y_test = torch.tensor(Y_test.values,dtype=torch.float).cuda()

# %% [markdown]
# # data iter

# %%
datasets = torch.utils.data.TensorDataset(X_train, Y_train)
train_iter = torch.utils.data.DataLoader(datasets, batch_size=256, shuffle=True)

# %%
datasets = torch.utils.data.TensorDataset(X_valid, Y_valid)
valid_iter = torch.utils.data.DataLoader(datasets, batch_size=256, shuffle=True)

# %% [markdown]
# # Construct the neural network

# %%
class energy_net(nn.Module):
    def __init__(self,input_shape,output_shape):
        super(energy_net,self).__init__()
        self.fc1 = Linear(input_shape,128)
        self.fc2 = Linear(128,output_shape)
        self.act_fn = Tanh()
    
    def forward(self,x):
        x = self.fc1(x)
        x = self.act_fn(x)
        x = self.fc2(x)
        return x

# %%
def init_weights(m):
    if hasattr(m,'weight'):
        torch.nn.init.xavier_uniform(m.weight)
    if hasattr(m,'bias'):
        m.bias.data.fill_(0)

# %%
net = energy_net(len(x_col),len(y_col)).cuda()
net.apply(init_weights)
# Out:
# energy_net(
#   (fc1): Linear(in_features=58, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=6, bias=True)
#   (act_fn): Tanh()
# )

# %% [markdown]
# # forward test

# %%
net(X_test)
# Out:
# tensor([[ 0.3013, -0.3094,  0.1884, -0.4721, -0.0173,  0.1437],
#         [ 0.0436, -0.3784, -0.1496, -0.3019, -0.0701,  0.2738],
#         [ 0.4926, -0.1655,  0.2253, -0.4494, -0.2395,  0.2757],
#         ...,
#         [ 0.3752, -0.1818,  0.1529, -0.4530, -0.0362,  0.1069],
#         [ 0.2486, -0.5644,  0.0823, -0.1575,  0.0013,  0.5449],
#         [ 0.2742,  0.0772, -0.1291, -0.7193,  0.0843, -0.0452]],
#        device='cuda:0', grad_fn=<AddmmBackward>)

# %% [markdown]
# # torchviz

# %%
y = net(X_test)
torchviz.make_dot(y.mean(),params=dict(net.named_parameters()))

# %% [markdown]
# # loss_function and optimizer

# %%
loss_function = nn.MSELoss()
optimizer = optim.Adam(net.parameters(),lr=0.001)

# %% [markdown]
# # train_loop

# %%
def train(net,train_iter,valid_iter,loss_function,optimizer,num_epochs=100):
    train_history = []
    valid_history = []
    best_loss = np.inf
    best_net = None
    
    for epoch in range(num_epochs):
        # train
        net.train()
        train_loss = 0
        t = 0
        for x,y in train_iter:
            loss = loss_function(net(x),y)
            # weight update
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            # record loss
            train_loss += loss.item()
            t += 1
        train_history.append(train_loss/t)
        
        # eval
        net.eval()
        valid_loss = 0
        t = 0
        for x,y in valid_iter:
            loss = loss_function(net(x),y)
            # record loss
            valid_loss += loss.item()
            t += 1
        valid_history.append(valid_loss/t)
        
        # print the epoch loss
        print("epochs {} train loss {:.4f} valid loss {:.4f}".format(
            epoch,train_history[-1],valid_history[-1]))
        
        # record best_net
        if valid_history[-1] <= best_loss:
            best_loss = valid_history[-1]
            best_net = net
            print('record net')
    
    # when end all epoch plot history
    plt.plot(np.array(train_history),label='train')
    plt.plot(np.array(valid_history),label='valid')
    plt.title('loss history')
    plt.legend()
    plt.show()
    
    # return best_net
    return best_net

# %%
net = train(net,train_iter,valid_iter,loss_function,optimizer,num_epochs=250)
# Out:
# epochs 0 train loss 0.8822 valid loss 0.1910
# record net
# record net
# epochs 225 train loss 0.0109 valid loss 0.0137
# epochs 226 train loss 0.0110 valid loss 0.0131
# epochs 227 train loss 0.0108 valid loss 0.0129
# epochs 228 train loss 0.0109 valid loss 0.0144
# epochs 229 train loss 0.0109 valid loss 0.0125
# record net
# epochs 230 train loss 0.0106 valid loss 0.0128
# epochs 231 train loss 0.0109 valid loss 0.0147
# epochs 232 train loss 0.0106 valid loss 0.0144
# epochs 233 train loss 0.0108 valid loss 0.0131
# epochs 234 train loss 0.0107 valid loss 0.0126
# epochs 235 train loss 0.0108 valid loss 0.0144
# epochs 236 train loss 0.0111 valid loss 0.0131
# epochs 237 train loss 0.0106 valid loss 0.0127
# epochs 238 train loss 0.0107 valid loss 0.0167
# epochs 239 train loss 0.0107 valid loss 0.0123
# record net
# epochs 240 train loss 0.0108 valid loss 0.0127
# epochs 241 train loss 0.0106 valid loss 0.0132
# epochs 242 train loss 0.0106 valid loss 0.0134
# epochs 243 train loss 0.0104 valid loss 0.0136
# epochs 244 train loss 0.0103 valid loss 0.0173
# epochs 245 train loss 0.0104 valid loss 0.0126
# epochs 246 train loss 0.0105 valid loss 0.0123
# record net
# epochs 247 train loss 0.0104 valid loss 0.0131
# epochs 248 train loss 0.0103 valid loss 0.0139
# epochs 249 train loss 0.0103 valid loss 0.0127

# %% [markdown]
# # make prediction

# %%
y_pred = net(X_test).cpu().detach().numpy()
y_pred = pd.DataFrame(y_pred,columns=y_col)
y_pred.head()
# Out:
#    Duty_E062 3.5K Steam Rate_ton/hr  Duty_Reboiler Heat Duty_Mkcal/hr  \
# 0                          2.452162                          4.760749
# 1                          2.172604                          3.602614
# 2                          2.399189                          3.930799
# 3                          2.271258                          4.100028
# 4                          2.159962                          4.939877
#
#    NA_density  LE_density  HC_density  HE_density
# 0    0.755767    0.678485    0.758649    0.778143
# 1    0.750946    0.686653    0.751917    0.769840
# 2    0.747791    0.681966    0.752214    0.780885
# 3    0.741953    0.691588    0.735938    0.767740
# 4    0.746449    0.684858    0.748879    0.775666

# %%
y_real = Y_test.cpu().detach().numpy()
y_real = pd.DataFrame(y_real,columns=y_col)
y_real.head()
# Out:
#    Duty_E062 3.5K Steam Rate_ton/hr  Duty_Reboiler Heat Duty_Mkcal/hr  \
# 0                          2.453458                          4.698574
# 1                          2.182361                          3.578535
# 2                          2.416492                          3.884625
# 3                          2.281401                          4.119564
# 4                          2.174843                          4.815617
#
#    NA_density  LE_density  HC_density  HE_density
# 0    0.749503    0.679052    0.761167    0.771581
# 1    0.748503    0.687001    0.749971    0.767770
# 2    0.746927    0.684940    0.753390    0.774844
# 3    0.736877    0.702585    0.737791    0.759862
# 4    0.746927    0.684444    0.754676    0.772336

# %% [markdown]
# # metric

# %%
res = pd.DataFrame(index=y_col,columns=['MSE','MAPE'])

for i in y_col:
    res.loc[i,'MSE'] = mean_squared_error(y_real[i],y_pred[i])
    res.loc[i,'MAPE'] = mape(y_real[i],y_pred[i])
res.loc['AVG'] = res.mean(axis=0)
res
# Out:
#                                           MSE      MAPE
# Duty_E062 3.5K Steam Rate_ton/hr  0.000344492  0.677012
# Duty_Reboiler Heat Duty_Mkcal/hr    0.0596809   2.87258
# NA_density                        2.58386e-05  0.515122
# LE_density                         4.0955e-05  0.632724
# HC_density                        1.82942e-05  0.406359
# HE_density                        4.59534e-05  0.722858
# AVG                                 0.0100261  0.971108

# %% [markdown]
# # wrap model

# %%
class ANN_energy_wrapper(object):
    def __init__(self,x_col,y_col,scaler,net):
        self.x_col = x_col
        self.y_col = y_col
        self.scaler = scaler
        self.net = net
    
    def predict(self,x):
        x = self.scaler.transform(x)
        x = torch.tensor(x,dtype=torch.float).cuda()
        y = self.net(x).detach().cpu().numpy()
        y = pd.DataFrame(y,columns=self.y_col)
        return y

# %%
model = ANN_energy_wrapper(x_col,y_col,mm,net.eval())

# %% [markdown]
# # test ANN_wrapper

# %%
df = pd.read_csv(root+'train(energy).csv',index_col=0).sample(1000).dropna(axis=0)
x = df[x_col]
duty = df[col_names['duty']].drop('Duty_Condenser Heat Duty_Mkcal/hr',axis=1)
density = df[col_names['Rate_ton']].values/df[col_names['Rate_m3']].values
density = pd.DataFrame(density,columns=['NA_density','LE_density','HC_density','HE_density'],index=df.index)
y_real = duty.join(density)

# %%
x.head()
# Out:
#         Case Conditions_Feed Rate to C013 (Input)_m3/hr  \
# 448-27                                             30.0
# 455-27                                             30.0
# 405-14                                             20.0
# 058-02                                             10.0
# 114-32                                             20.0
#
#         Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr  \
# 448-27                                              100.0
# 455-27                                              100.0
# 405-14                                              100.0
# 058-02                                              100.0
# 114-32                                               90.0
#
#         Case Conditions_C7+ in Light End (Input)_wt%  \
# 448-27                                          10.0
# 455-27                                          10.0
# 405-14                                           5.0
# 058-02                                           5.0
# 114-32                                           2.5
#
#         Case Conditions_C6P- in Heart Cut (Input)_wt%  \
# 448-27                                            0.5
# 455-27                                            2.0
# 405-14                                            0.7
# 058-02                                            1.0
# 114-32                                            1.0
#
#         Naphtha Properties_Oxygen_wt%  Naphtha Properties_Methane_wt%  \
# 448-27                            0.0                             0.0
# 455-27                            0.0                             0.0
# 405-14                            0.0                             0.0
# 058-02                            0.0                             0.0
# 114-32                            0.0                             0.0
#
#         Naphtha Properties_Ethane_wt%  Naphtha Properties_Propane_wt%  \
# 448-27                            0.0                        0.039999
# 455-27                            0.0                        0.069001
# 405-14                            0.0                        0.032000
# 058-02                            0.0                        0.001000
# 114-32                            0.0                        0.017000
#
#         Naphtha Properties_n-Butane_wt%  Naphtha Properties_i-Pentane_wt%  \
# 448-27                         0.079998                          0.661987
# 455-27                         0.139001                          1.152012
# 405-14                         0.063001                          0.524005
# 058-02                         0.002000                          0.017001
# 114-32                         0.035000                          0.289003
#
#         ...  Naphtha Properties_2,2,3,3-Tetramethylhexane_wt%  \
# 448-27  ...                                          0.912982
# 455-27  ...                                          0.922009
# 405-14  ...                                          0.947010
# 058-02  ...                                          1.129045
# 114-32  ...                                          1.055011
#
#         Naphtha Properties_3-Methylnonane_wt%  \
# 448-27                               2.131957
# 455-27                               2.151022
# 405-14                               2.209023
# 058-02                               2.635105
# 114-32                               2.463025
#
#         Naphtha Properties_tert-Butylcyclohexane_wt%  \
# 448-27                                      0.960981
# 455-27                                      0.904009
# 405-14                                      0.987010
# 058-02                                      0.356014
# 114-32                                      0.534005
#
#         Naphtha Properties_n-Decane_wt%  \
# 448-27                         0.501990
# 455-27                         0.448005
# 405-14                         0.498005
# 058-02                         0.517021
# 114-32                         0.671007
#
#         Naphtha Properties_1,2-Diethylbenzene_wt%  \
# 448-27                                   0.523989
# 455-27                                   1.075011
# 405-14                                   0.510005
# 058-02                                   0.217009
# 114-32                                   0.303003
#
#         Naphtha Properties_n-Undecane_wt%  \
# 448-27                           0.094998
# 455-27                           0.085001
# 405-14                           0.094001
# 058-02                           0.098004
# 114-32                           0.127001
#
#         Naphtha Properties_n-Pentylbenzene_wt%  \
# 448-27                                0.029999
# 455-27                                0.062001
# 405-14                                0.030000
# 058-02                                0.013001
# 114-32                                0.018000
#
#         Naphtha Properties_n-Dodecane_wt%  \
# 448-27                              0.002
# 455-27                              0.002
# 405-14                              0.002
# 058-02                              0.002
# 114-32                              0.002
#
#         Naphtha Properties_n-Hexylbenzene_wt%  \
# 448-27                                  0.006
# 455-27                                  0.012
# 405-14                                  0.006
# 058-02                                  0.002
# 114-32                                  0.003
#
#         Naphtha Properties_n-Tridecane_wt%
# 448-27                                 0.0
# 455-27                                 0.0
# 405-14                                 0.0
# 058-02                                 0.0
# 114-32                                 0.0
#
# [5 rows x 58 columns]

# %% [markdown]
# # y_real

# %%
y_real.head()
# Out:
#         Duty_E062 3.5K Steam Rate_ton/hr  Duty_Reboiler Heat Duty_Mkcal/hr  \
# 448-27                          2.266938                          5.490885
# 455-27                          2.327591                          3.080163
# 405-14                          2.225852                          3.707399
# 058-02                          2.208823                          3.352943
# 114-32                          2.081470                          4.337372
#
#         NA_density  LE_density  HC_density  HE_density
# 448-27    0.756362    0.702844    0.761336    0.791600
# 455-27    0.750819    0.676978    0.756295    0.784360
# 405-14    0.752865    0.694490    0.756289    0.769259
# 058-02    0.738548    0.693027    0.738530    0.761070
# 114-32    0.740084    0.685597    0.743469    0.763897

# %% [markdown]
# # y_pred

# %%
y_pred = model.predict(x)
y_pred.head()
# Out:
#    Duty_E062 3.5K Steam Rate_ton/hr  Duty_Reboiler Heat Duty_Mkcal/hr  \
# 0                          2.269437                          5.697036
# 1                          2.315627                          3.136480
# 2                          2.227696                          3.712823
# 3                          2.193311                          3.260161
# 4                          2.069693                          4.457173
#
#    NA_density  LE_density  HC_density  HE_density
# 0    0.757187    0.689550    0.763183    0.797499
# 1    0.748771    0.679894    0.756581    0.792576
# 2    0.758630    0.688313    0.755286    0.779073
# 3    0.739712    0.689829    0.742730    0.769092
# 4    0.737828    0.688550    0.742534    0.766135

# %%
res = pd.DataFrame(index=y_col,columns=['MSE','MAPE'])

for i in y_col:
    res.loc[i,'MSE'] = mean_squared_error(y_real[i],y_pred[i])
    res.loc[i,'MAPE'] = mape(y_real[i],y_pred[i])
res.loc['AVG'] = res.mean(axis=0)
res
# Out:
#                                           MSE      MAPE
# Duty_E062 3.5K Steam Rate_ton/hr  0.000338061  0.665807
# Duty_Reboiler Heat Duty_Mkcal/hr    0.0669642   2.74105
# NA_density                        2.36604e-05  0.498367
# LE_density                        3.04195e-05  0.575301
# HC_density                        1.63773e-05  0.391777
# HE_density                        4.63645e-05  0.722563
# AVG                                 0.0112365  0.932477

# %% [markdown]
# # save model

# %%
joblib.dump(model,'../model/ANN(energy).pkl')
print('save done!')
# Out:
# save done!
